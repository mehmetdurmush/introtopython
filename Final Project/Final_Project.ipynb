# %%
print("GUESS THE CAPITAL CITY")
score=0
question_one = input("Where is the capital city of Turkey?: ")
if question_one == "Ankara":
    print("Correct answer +10 points")
    score += 10
else:
    print("Wrong answer")
question_two = input("Where is the capital city of Netherlands?: ")
if question_two == "Amsterdam":
    print("Correct answer +10 points")
    score += 10
else:
    print("Wrong answer")
question_three = input("Where is the capital city of Germany?: ")
if question_three== "Berlin":
    print("Correct answer +10 points")
    score += 10
else:
    print("Wrong answer")
question_four = input("Where is the capital city of Sweden?: ")
if question_four== "Stockholm":
    print("Correct answer +10 points")
    score += 10
else:
    print("Wrong answer")
question_five = input("Where is the capital city of China?: ")
if question_five== "Beijing":
    print("Correct answer +10 points")
    score += 10
else:
    print("Wrong answer")
question_six = input("Where is the capital city of India?: ")
if question_six== "New Delhi":
    print("Correct answer +10 points")
    score += 10
else:
    print("Wrong answer")
question_seven = input("Where is the capital city of Iceland?: ")
if question_seven== "Reykjavik":
    print("Correct answer +10 points")
    score += 10
else:
    print("Wrong answer")
question_eight = input("Where is the capital city of Indonesia?: ")
if question_eight== "Jakarta":
    print("Correct answer +10 points")
    score += 10
else:
    print("Wrong answer")
question_nine = input("Where is the capital city of Australia?: ")
if question_nine== "Canberra":
    print("Correct answer +10 points")
    score += 10
else:
    print("Wrong answer")
question_ten = input("Where is the capital city of Uganda?: ")
if question_ten== "Kampala":
    print("Correct answer +10 points")
    score += 10
else:
    print("Wrong answer")


if score>50:
    print("Congrats, you passed the quiz! \
    Your score: ",score)
else:
    print("Sorry, you failed quiz \
    Your score: ",score)
