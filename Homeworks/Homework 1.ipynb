# %%
odd_numbers = [1,3,5,7,9]
even_numbers = [0,2,4,6,8,10]

# %%
combined_list = []
for i in odd_numbers + even_numbers:
    combined_list.append(i*2)
combined_list
# Out:
# [2, 6, 10, 14, 18, 0, 4, 8, 12, 16, 20]

# %%
for i in combined_list:
    print(type(i))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
