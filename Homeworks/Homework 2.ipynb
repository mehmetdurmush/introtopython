# %%
ahmetin_cvsi= {"Adı":"Ahmet",
               "Soyadı":"Yılmaz",
              "Eğitim":"Ege Ünivesitesi İşletme Bölümü Lisans",
              "Bildiği Diller":"İngilizce, Almanca",
              "Tecrübe":"3 Yıl",
              "Askerlik Durumu":"Yapıldı",
              "Hobiler":"Spor yapmak,müzik dinlemek",
              "Yaşadığı Şehir":"Manisa"}

# %%
silanin_cvsi = {"Adı":"Sıla",
               "Soyadı":"Uçar",
              "Eğitim":"Medipol Üniversitesi Yönetim Blişim Sistemleri Lisans",
              "Bildiği Diller":"İngilizce",
              "Tecrübe":"1 Yıl",
               "Hobiler":"kitap okumak,film izlemek",
               "Yaşadığı Şehir":"İstanbul"}

# %%
dilanin_cvsi = {"Adı":"Dilan",
               "Soyadı":"Eroğlu", 
              "Eğitim":"Yeditepe Üniversitesi Uluslarası İlişkiler Lisans",
              "Bildiği Diller":"İngilizce, Fransızca",
              "Tecrübe":"2 Yıl",
               "Hobiler":"Tiyatroya gitmek",
               "Yaşadığı Şehir":"Ankara"}

# %%
yusufun_cvsi = {"Adı":"Yusuf",
               "Soyadı":"Tatar",
              "Eğitim":"İzmir Atatürk Anadolu Lisesi",
              "Bildiği Diller":"İngilizce",
              "Tecrübe":"8 Yıl",
              "Askerlik Durumu":"Yapıldı",
              "Hobiler":"Yemek yapmak",
              "Yaşadığı Şehir":"İzmir"}

# %%
cerenin_cvsi = {"Adı":"Ceren",
               "Soyadı":"Abacı", 
              "Eğitim":"Mardin Artuklu Üniversitesi İşletme Lisans",
              "Bildiği Diller":"İngilizce",
              "Tecrübe":"4 Yıl",
               "Hobiler":"Kitap okumak, yürüyüş yapmak",
               "Yaşadığı Şehir":"Tokat"}

# %%
all_cvs = [cerenin_cvsi, yusufun_cvsi, dilanin_cvsi,silanin_cvsi, ahmetin_cvsi]

# %%
for i in all_cvs:
    print(i)
# Out:
# {'Adı': 'Ceren', 'Soyadı': 'Abacı', 'Eğitim': 'Mardin Artuklu Üniversitesi İşletme Lisans', 'Bildiği Diller': 'İngilizce', 'Tecrübe': '4 Yıl', 'Hobiler': 'Kitap okumak, yürüyüş yapmak', 'Yaşadığı Şehir': 'Tokat'}
# {'Adı': 'Yusuf', 'Soyadı': 'Tatar', 'Eğitim': 'İzmir Atatürk Anadolu Lisesi', 'Bildiği Diller': 'İngilizce', 'Tecrübe': '8 Yıl', 'Askerlik Durumu': 'Yapıldı', 'Hobiler': 'Yemek yapmak', 'Yaşadığı Şehir': 'İzmir'}
# {'Adı': 'Dilan', 'Soyadı': 'Eroğlu', 'Eğitim': 'Yeditepe Üniversitesi Uluslarası İlişkiler Lisans', 'Bildiği Diller': 'İngilizce, Fransızca', 'Tecrübe': '2 Yıl', 'Hobiler': 'Tiyatroya gitmek', 'Yaşadığı Şehir': 'Ankara'}
# {'Adı': 'Sıla', 'Soyadı': 'Uçar', 'Eğitim': 'Medipol Üniversitesi Yönetim Blişim Sistemleri Lisans', 'Bildiği Diller': 'İngilizce', 'Tecrübe': '1 Yıl', 'Hobiler': 'kitap okumak,film izlemek', 'Yaşadığı Şehir': 'İstanbul'}
# ...
